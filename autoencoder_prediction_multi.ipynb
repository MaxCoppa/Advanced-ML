# %%
# !pip install tqdm polars scikit-learn matplotlib
# Out:
# Requirement already satisfied: tqdm in /opt/python/lib/python3.13/site-packages (4.67.1)
# Requirement already satisfied: polars in /opt/python/lib/python3.13/site-packages (1.35.2)
# Requirement already satisfied: scikit-learn in /opt/python/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: matplotlib in /opt/python/lib/python3.13/site-packages (3.10.7)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /opt/python/lib/python3.13/site-packages (from polars) (1.35.2)
# Requirement already satisfied: numpy>=1.22.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/python/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/python/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/python/lib/python3.13/site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/python/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/python/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/python/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/python/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/python/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import torch
from data_loader import S3ParquetReader
from config import USER
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from models import AutoEncoder, train_model, CombinedLoss
from torch.optim import Adam

# %% [markdown]
# ## Data Loading

# %% [markdown]
# Config initialisation

# %%
BUCKET = f"/{USER}/jane_street_data"
reader = S3ParquetReader(bucket=BUCKET)
FILE_KEY_S3 = "preprocessed.parquet/data_clean_symb_1.parquet"

# %%
data = reader.read_parquet(FILE_KEY_S3)
data.head()
# Out:
# shape: (5, 79)
# ┌─────────┬─────────┬───────────┬──────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ date_id ┆ time_id ┆ symbol_id ┆ weight   ┆ … ┆ responder_ ┆ responder_ ┆ responder_ ┆ responder_ │
# │ ---     ┆ ---     ┆ ---       ┆ ---      ┆   ┆ 5          ┆ 6          ┆ 7          ┆ 8          │
# │ i16     ┆ i16     ┆ i8        ┆ f32      ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │         ┆         ┆           ┆          ┆   ┆ f32        ┆ f32        ┆ f32        ┆ f32        │
# ╞═════════╪═════════╪═══════════╪══════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 0       ┆ 34      ┆ 1         ┆ 3.889038 ┆ … ┆ -0.434355  ┆ -1.220439  ┆ 0.214211   ┆ -0.257941  │
# │ 0       ┆ 35      ┆ 1         ┆ 3.889038 ┆ … ┆ -0.112329  ┆ -1.233082  ┆ 0.131704   ┆ -0.024239  │
# │ 0       ┆ 36      ┆ 1         ┆ 3.889038 ┆ … ┆ 0.419467   ┆ -0.578848  ┆ 0.269364   ┆ 0.459819   │
# │ 0       ┆ 37      ┆ 1         ┆ 3.889038 ┆ … ┆ 0.321798   ┆ -0.683034  ┆ 0.027111   ┆ 0.075722   │
# │ 0       ┆ 38      ┆ 1         ┆ 3.889038 ┆ … ┆ 0.098249   ┆ -0.606483  ┆ -0.01076   ┆ -0.134628  │
# └─────────┴─────────┴───────────┴──────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# Ensure sorted by time_id to create batches not leaked

# %%
data = data.sort(by="time_id")

# %% [markdown]
# Define features and target

# %%
target = "responder_6"
features = [col for col in data.columns if "feature" in col]

X, y = data[features], data[target]

# %% [markdown]
# Split data

# %%
n = X.height
n_train = int(0.8 * n)
X_train = X.slice(0, n_train)
y_train = y.slice(0, n_train)

X_val = X.slice(n_train)
y_val = y.slice(n_train)

# %% [markdown]
# Data Wraper

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X.to_numpy(), dtype=torch.float32)
        y = torch.tensor(y.to_numpy(), dtype=torch.float32)
        if y.ndim == 1:
            y = y.view(-1, 1)
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %% [markdown]
# Add w

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, X, y, w=10):
        self.w = w
        self.X = torch.tensor(X.to_numpy(), dtype=torch.float32)
        y = torch.tensor(y.to_numpy(), dtype=torch.float32)
        if y.ndim == 1:
            y = y.view(-1, 1)
        self.y = y

        # Number of valid samples given the w
        self.n_samples = len(self.X) - self.w + 1

    def __len__(self):
        return self.n_samples

    def __getitem__(self, idx):
        """
        Returns:
        - X_w: shape (w, n_features)
        - y_target: target corresponding to the last time step of the w
        """
        X_w = self.X[idx : idx + self.w].reshape(-1)
        y_target = self.y[idx + (self.w - 1)]
        return X_w, y_target

# %%
w = 10

# %%
train_dataset = TimeSeriesDataset(X_train, y_train, w=w)
val_dataset = TimeSeriesDataset(X_val, y_val, w=w)

# %%
train_data_loader = DataLoader(
    train_dataset, batch_size=2048, shuffle=False, num_workers=8
)
val_data_loader = DataLoader(val_dataset, batch_size=2048, shuffle=False, num_workers=8)

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Model hyperameters

# %%
n_feat = w * len(features)
n_latent = 48
encoder_hidden = [128, 64]
decoder_hidden = [64, 128]
head_hidden = [32, 8]
dropouts = (0.1, 0.1, 0.2)
batch_norms = (True, True, True)

# %%
model = AutoEncoder(
    n_feat=n_feat,
    n_latent=n_latent,
    encoder_hidden=encoder_hidden,
    decoder_hidden=decoder_hidden,
    head_hidden=head_hidden,
    dropouts=dropouts,
    batch_norms=batch_norms,
)

# %% [markdown]
# Training hyperparameters

# %%
lr = 1e-3
device = torch.device("cuda")
alpha = 0.1
beta = 0.9

# %%
optimizer = Adam(model.parameters(), lr=lr)
criterion = CombinedLoss(alpha=alpha, beta=beta)
n_epochs = 100

# %%
train_model(
    model=model,
    train_loader=train_data_loader,
    val_loader=val_data_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    n_epochs=n_epochs,
)
# Out:
# Epoch 01 | loss=2239.278 | R2_rec_train=-31.2421 | R2_rec_val=0.0691 | R2_sup_train=-0.0276 | R2_sup_val=-0.0055
# Epoch 02 | loss=277.467 | R2_rec_train=-0.1389 | R2_rec_val=0.1063 | R2_sup_train=0.0001 | R2_sup_val=-0.0032
# Epoch 03 | loss=269.020 | R2_rec_train=-0.0199 | R2_rec_val=0.1237 | R2_sup_train=0.0057 | R2_sup_val=-0.0033
# Epoch 04 | loss=266.124 | R2_rec_train=0.0085 | R2_rec_val=0.1263 | R2_sup_train=0.0115 | R2_sup_val=-0.0054
# Epoch 05 | loss=264.162 | R2_rec_train=0.0216 | R2_rec_val=0.1218 | R2_sup_train=0.0165 | R2_sup_val=-0.0130
# Epoch 06 | loss=261.942 | R2_rec_train=0.0327 | R2_rec_val=0.1261 | R2_sup_train=0.0241 | R2_sup_val=-0.0158
# Epoch 07 | loss=260.163 | R2_rec_train=0.0367 | R2_rec_val=0.1629 | R2_sup_train=0.0311 | R2_sup_val=-0.0143
# Epoch 08 | loss=256.901 | R2_rec_train=0.0547 | R2_rec_val=0.1699 | R2_sup_train=0.0411 | R2_sup_val=-0.0286
# Epoch 09 | loss=253.880 | R2_rec_train=0.0630 | R2_rec_val=0.1803 | R2_sup_train=0.0520 | R2_sup_val=-0.0598
# Epoch 10 | loss=250.709 | R2_rec_train=0.0702 | R2_rec_val=0.1854 | R2_sup_train=0.0638 | R2_sup_val=-0.0807
# Epoch 11 | loss=247.546 | R2_rec_train=0.0745 | R2_rec_val=0.1863 | R2_sup_train=0.0764 | R2_sup_val=-0.1001
# Epoch 12 | loss=244.538 | R2_rec_train=0.0801 | R2_rec_val=0.1898 | R2_sup_train=0.0878 | R2_sup_val=-0.1301
# Epoch 13 | loss=242.536 | R2_rec_train=0.0843 | R2_rec_val=0.1859 | R2_sup_train=0.0978 | R2_sup_val=-0.0760
# Epoch 14 | loss=241.257 | R2_rec_train=0.0733 | R2_rec_val=0.1936 | R2_sup_train=0.1039 | R2_sup_val=-0.1145
# Epoch 15 | loss=237.641 | R2_rec_train=0.0889 | R2_rec_val=0.1979 | R2_sup_train=0.1161 | R2_sup_val=-0.0951
# Epoch 16 | loss=234.785 | R2_rec_train=0.0943 | R2_rec_val=0.2001 | R2_sup_train=0.1273 | R2_sup_val=-0.1127
# Epoch 17 | loss=232.728 | R2_rec_train=0.0981 | R2_rec_val=0.2012 | R2_sup_train=0.1358 | R2_sup_val=-0.1353
# Epoch 18 | loss=230.924 | R2_rec_train=0.1006 | R2_rec_val=0.2021 | R2_sup_train=0.1429 | R2_sup_val=-0.1324
# Epoch 19 | loss=228.521 | R2_rec_train=0.1037 | R2_rec_val=0.2049 | R2_sup_train=0.1526 | R2_sup_val=-0.1031
# Epoch 20 | loss=226.277 | R2_rec_train=0.1051 | R2_rec_val=0.2042 | R2_sup_train=0.1620 | R2_sup_val=-0.1137
# Epoch 21 | loss=224.688 | R2_rec_train=0.1065 | R2_rec_val=0.2086 | R2_sup_train=0.1689 | R2_sup_val=-0.1329
# Epoch 22 | loss=222.899 | R2_rec_train=0.1077 | R2_rec_val=0.2073 | R2_sup_train=0.1759 | R2_sup_val=-0.1225
# Epoch 23 | loss=221.302 | R2_rec_train=0.1093 | R2_rec_val=0.2074 | R2_sup_train=0.1827 | R2_sup_val=-0.1383
# Epoch 24 | loss=219.897 | R2_rec_train=0.1084 | R2_rec_val=0.2101 | R2_sup_train=0.1890 | R2_sup_val=-0.1420
# Epoch 25 | loss=218.337 | R2_rec_train=0.1116 | R2_rec_val=0.2125 | R2_sup_train=0.1951 | R2_sup_val=-0.1315
# Epoch 26 | loss=217.049 | R2_rec_train=0.1131 | R2_rec_val=0.2129 | R2_sup_train=0.2002 | R2_sup_val=-0.1529
# Epoch 27 | loss=215.842 | R2_rec_train=0.1140 | R2_rec_val=0.2105 | R2_sup_train=0.2052 | R2_sup_val=-0.1755
# Epoch 28 | loss=214.515 | R2_rec_train=0.1137 | R2_rec_val=0.2126 | R2_sup_train=0.2108 | R2_sup_val=-0.1142
# Epoch 29 | loss=213.463 | R2_rec_train=0.1163 | R2_rec_val=0.2151 | R2_sup_train=0.2148 | R2_sup_val=-0.1425
# Epoch 30 | loss=212.285 | R2_rec_train=0.1166 | R2_rec_val=0.2107 | R2_sup_train=0.2197 | R2_sup_val=-0.1571
# Epoch 31 | loss=211.326 | R2_rec_train=0.1152 | R2_rec_val=0.2138 | R2_sup_train=0.2242 | R2_sup_val=-0.1382
# Epoch 32 | loss=210.506 | R2_rec_train=0.1187 | R2_rec_val=0.2156 | R2_sup_train=0.2271 | R2_sup_val=-0.1229
# Epoch 33 | loss=208.783 | R2_rec_train=0.1194 | R2_rec_val=0.2141 | R2_sup_train=0.2342 | R2_sup_val=-0.1327
# Epoch 34 | loss=208.238 | R2_rec_train=0.1200 | R2_rec_val=0.2141 | R2_sup_train=0.2363 | R2_sup_val=-0.1212
# Epoch 35 | loss=207.512 | R2_rec_train=0.1201 | R2_rec_val=0.2111 | R2_sup_train=0.2394 | R2_sup_val=-0.1627
# Epoch 36 | loss=206.559 | R2_rec_train=0.1208 | R2_rec_val=0.2167 | R2_sup_train=0.2436 | R2_sup_val=-0.1337
# Epoch 37 | loss=205.899 | R2_rec_train=0.1225 | R2_rec_val=0.2166 | R2_sup_train=0.2459 | R2_sup_val=-0.1430
# Epoch 38 | loss=204.593 | R2_rec_train=0.1236 | R2_rec_val=0.2171 | R2_sup_train=0.2512 | R2_sup_val=-0.1817
# Epoch 39 | loss=204.068 | R2_rec_train=0.1249 | R2_rec_val=0.2116 | R2_sup_train=0.2534 | R2_sup_val=-0.1553
# Epoch 40 | loss=203.706 | R2_rec_train=0.1235 | R2_rec_val=0.2159 | R2_sup_train=0.2552 | R2_sup_val=-0.1379
# Epoch 41 | loss=202.665 | R2_rec_train=0.1250 | R2_rec_val=0.2122 | R2_sup_train=0.2591 | R2_sup_val=-0.1455
# Epoch 42 | loss=201.800 | R2_rec_train=0.1261 | R2_rec_val=0.2180 | R2_sup_train=0.2626 | R2_sup_val=-0.1123
# Epoch 43 | loss=201.009 | R2_rec_train=0.1273 | R2_rec_val=0.2167 | R2_sup_train=0.2658 | R2_sup_val=-0.1344
# Epoch 44 | loss=200.381 | R2_rec_train=0.1273 | R2_rec_val=0.2195 | R2_sup_train=0.2685 | R2_sup_val=-0.1438
# Epoch 45 | loss=200.285 | R2_rec_train=0.1287 | R2_rec_val=0.2238 | R2_sup_train=0.2689 | R2_sup_val=-0.1206
# Epoch 46 | loss=199.154 | R2_rec_train=0.1283 | R2_rec_val=0.2156 | R2_sup_train=0.2737 | R2_sup_val=-0.1509
# Epoch 47 | loss=198.808 | R2_rec_train=0.1300 | R2_rec_val=0.2157 | R2_sup_train=0.2746 | R2_sup_val=-0.1523
# Epoch 48 | loss=198.088 | R2_rec_train=0.1306 | R2_rec_val=0.2173 | R2_sup_train=0.2775 | R2_sup_val=-0.1566
# Epoch 49 | loss=197.754 | R2_rec_train=0.1314 | R2_rec_val=0.2154 | R2_sup_train=0.2787 | R2_sup_val=-0.1460
# Epoch 50 | loss=196.842 | R2_rec_train=0.1322 | R2_rec_val=0.2177 | R2_sup_train=0.2825 | R2_sup_val=-0.1621
# Epoch 51 | loss=196.348 | R2_rec_train=0.1338 | R2_rec_val=0.2203 | R2_sup_train=0.2843 | R2_sup_val=-0.1419
# Epoch 52 | loss=196.043 | R2_rec_train=0.1340 | R2_rec_val=0.2171 | R2_sup_train=0.2854 | R2_sup_val=-0.1448
# Epoch 53 | loss=195.464 | R2_rec_train=0.1351 | R2_rec_val=0.2165 | R2_sup_train=0.2880 | R2_sup_val=-0.1371
# Epoch 54 | loss=194.979 | R2_rec_train=0.1361 | R2_rec_val=0.2198 | R2_sup_train=0.2897 | R2_sup_val=-0.1495
# Epoch 55 | loss=194.288 | R2_rec_train=0.1366 | R2_rec_val=0.2185 | R2_sup_train=0.2925 | R2_sup_val=-0.1449
# Epoch 56 | loss=193.808 | R2_rec_train=0.1378 | R2_rec_val=0.2193 | R2_sup_train=0.2942 | R2_sup_val=-0.1431
# Epoch 57 | loss=193.397 | R2_rec_train=0.1384 | R2_rec_val=0.2192 | R2_sup_train=0.2959 | R2_sup_val=-0.1632
# Epoch 58 | loss=192.813 | R2_rec_train=0.1397 | R2_rec_val=0.2161 | R2_sup_train=0.2981 | R2_sup_val=-0.1615
# Epoch 59 | loss=192.638 | R2_rec_train=0.1398 | R2_rec_val=0.2150 | R2_sup_train=0.2987 | R2_sup_val=-0.1592
# Epoch 60 | loss=191.735 | R2_rec_train=0.1411 | R2_rec_val=0.2171 | R2_sup_train=0.3024 | R2_sup_val=-0.1266
# Epoch 61 | loss=191.477 | R2_rec_train=0.1422 | R2_rec_val=0.2184 | R2_sup_train=0.3031 | R2_sup_val=-0.1587
# Epoch 62 | loss=191.009 | R2_rec_train=0.1427 | R2_rec_val=0.2158 | R2_sup_train=0.3051 | R2_sup_val=-0.1389
# Epoch 63 | loss=190.875 | R2_rec_train=0.1433 | R2_rec_val=0.2171 | R2_sup_train=0.3057 | R2_sup_val=-0.1288
# Epoch 64 | loss=189.946 | R2_rec_train=0.1436 | R2_rec_val=0.2201 | R2_sup_train=0.3093 | R2_sup_val=-0.1528
# Epoch 65 | loss=190.193 | R2_rec_train=0.1452 | R2_rec_val=0.2195 | R2_sup_train=0.3081 | R2_sup_val=-0.1266
# Epoch 66 | loss=189.686 | R2_rec_train=0.1462 | R2_rec_val=0.2178 | R2_sup_train=0.3100 | R2_sup_val=-0.1463
# Epoch 67 | loss=189.244 | R2_rec_train=0.1472 | R2_rec_val=0.2142 | R2_sup_train=0.3116 | R2_sup_val=-0.1315
# Epoch 68 | loss=189.260 | R2_rec_train=0.1479 | R2_rec_val=0.2213 | R2_sup_train=0.3113 | R2_sup_val=-0.1411
# Epoch 69 | loss=188.728 | R2_rec_train=0.1488 | R2_rec_val=0.2176 | R2_sup_train=0.3132 | R2_sup_val=-0.1456
# Epoch 70 | loss=188.152 | R2_rec_train=0.1493 | R2_rec_val=0.2092 | R2_sup_train=0.3158 | R2_sup_val=-0.1494
# Epoch 71 | loss=187.927 | R2_rec_train=0.1503 | R2_rec_val=0.2168 | R2_sup_train=0.3163 | R2_sup_val=-0.1568
# Epoch 72 | loss=187.537 | R2_rec_train=0.1511 | R2_rec_val=0.2180 | R2_sup_train=0.3179 | R2_sup_val=-0.1471
# Epoch 73 | loss=186.978 | R2_rec_train=0.1518 | R2_rec_val=0.2196 | R2_sup_train=0.3201 | R2_sup_val=-0.1292
# Epoch 74 | loss=186.912 | R2_rec_train=0.1528 | R2_rec_val=0.2178 | R2_sup_train=0.3205 | R2_sup_val=-0.1528
# Epoch 75 | loss=186.294 | R2_rec_train=0.1533 | R2_rec_val=0.2169 | R2_sup_train=0.3227 | R2_sup_val=-0.1533
# Epoch 76 | loss=186.613 | R2_rec_train=0.1547 | R2_rec_val=0.2168 | R2_sup_train=0.3211 | R2_sup_val=-0.1492
# Epoch 77 | loss=186.093 | R2_rec_train=0.1551 | R2_rec_val=0.2144 | R2_sup_train=0.3232 | R2_sup_val=-0.1413
# Epoch 78 | loss=185.647 | R2_rec_train=0.1564 | R2_rec_val=0.2209 | R2_sup_train=0.3248 | R2_sup_val=-0.1244
# Epoch 79 | loss=185.242 | R2_rec_train=0.1565 | R2_rec_val=0.2211 | R2_sup_train=0.3265 | R2_sup_val=-0.1406
# Epoch 80 | loss=184.822 | R2_rec_train=0.1575 | R2_rec_val=0.2208 | R2_sup_train=0.3281 | R2_sup_val=-0.1536
# Epoch 81 | loss=184.959 | R2_rec_train=0.1583 | R2_rec_val=0.2177 | R2_sup_train=0.3273 | R2_sup_val=-0.1601
# Epoch 82 | loss=184.500 | R2_rec_train=0.1597 | R2_rec_val=0.2228 | R2_sup_train=0.3291 | R2_sup_val=-0.1578
# Epoch 83 | loss=184.406 | R2_rec_train=0.1598 | R2_rec_val=0.2225 | R2_sup_train=0.3293 | R2_sup_val=-0.1546
# Epoch 84 | loss=184.209 | R2_rec_train=0.1608 | R2_rec_val=0.2180 | R2_sup_train=0.3299 | R2_sup_val=-0.1497
# Epoch 85 | loss=183.773 | R2_rec_train=0.1617 | R2_rec_val=0.2218 | R2_sup_train=0.3317 | R2_sup_val=-0.1368
# Epoch 86 | loss=183.822 | R2_rec_train=0.1621 | R2_rec_val=0.2190 | R2_sup_train=0.3314 | R2_sup_val=-0.1334
# Epoch 87 | loss=183.544 | R2_rec_train=0.1621 | R2_rec_val=0.2186 | R2_sup_train=0.3326 | R2_sup_val=-0.1428
# Epoch 88 | loss=183.359 | R2_rec_train=0.1640 | R2_rec_val=0.2260 | R2_sup_train=0.3330 | R2_sup_val=-0.1332
# Epoch 89 | loss=182.935 | R2_rec_train=0.1645 | R2_rec_val=0.2177 | R2_sup_train=0.3346 | R2_sup_val=-0.1727
# Epoch 90 | loss=182.742 | R2_rec_train=0.1652 | R2_rec_val=0.2259 | R2_sup_train=0.3352 | R2_sup_val=-0.1538
# Epoch 91 | loss=182.275 | R2_rec_train=0.1658 | R2_rec_val=0.2130 | R2_sup_train=0.3372 | R2_sup_val=-0.1352
# Epoch 92 | loss=182.275 | R2_rec_train=0.1668 | R2_rec_val=0.2237 | R2_sup_train=0.3373 | R2_sup_val=-0.1310
# Epoch 93 | loss=181.999 | R2_rec_train=0.1674 | R2_rec_val=0.2248 | R2_sup_train=0.3381 | R2_sup_val=-0.1330
# Epoch 94 | loss=181.950 | R2_rec_train=0.1680 | R2_rec_val=0.2279 | R2_sup_train=0.3380 | R2_sup_val=-0.1316
# Epoch 95 | loss=181.797 | R2_rec_train=0.1687 | R2_rec_val=0.2252 | R2_sup_train=0.3387 | R2_sup_val=-0.1507
# Epoch 96 | loss=181.412 | R2_rec_train=0.1700 | R2_rec_val=0.2244 | R2_sup_train=0.3400 | R2_sup_val=-0.1548
# Epoch 97 | loss=181.538 | R2_rec_train=0.1706 | R2_rec_val=0.2215 | R2_sup_train=0.3395 | R2_sup_val=-0.1488
# Epoch 98 | loss=180.913 | R2_rec_train=0.1709 | R2_rec_val=0.2242 | R2_sup_train=0.3418 | R2_sup_val=-0.1484
# Epoch 99 | loss=180.832 | R2_rec_train=0.1722 | R2_rec_val=0.2302 | R2_sup_train=0.3419 | R2_sup_val=-0.1610
# Epoch 100 | loss=180.635 | R2_rec_train=0.1719 | R2_rec_val=0.2245 | R2_sup_train=0.3430 | R2_sup_val=-0.1532
# True
