# %%
# !pip install scikit-learn xgboost
# Out:
# Requirement already satisfied: scikit-learn in /opt/python/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: xgboost in /opt/python/lib/python3.13/site-packages (3.1.2)
# Requirement already satisfied: numpy>=1.22.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /opt/python/lib/python3.13/site-packages (from xgboost) (2.27.5)

# %%
from data_loader import S3ParquetReader
from config import USER
from xgboost import XGBRegressor
from sklearn.metrics import r2_score

# %% [markdown]
# ## Data Loading

# %% [markdown]
# Config initialisation

# %%
BUCKET = f"/{USER}/jane_street_data"
reader = S3ParquetReader(bucket=BUCKET)
FILE_KEY_S3 = "preprocessed.parquet/data_clean_symb_1.parquet"

# %%
data = reader.read_parquet(FILE_KEY_S3)
data.head()
# Out:
# shape: (5, 79)
# ┌─────────┬─────────┬───────────┬──────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ date_id ┆ time_id ┆ symbol_id ┆ weight   ┆ … ┆ responder_ ┆ responder_ ┆ responder_ ┆ responder_ │
# │ ---     ┆ ---     ┆ ---       ┆ ---      ┆   ┆ 5          ┆ 6          ┆ 7          ┆ 8          │
# │ i16     ┆ i16     ┆ i8        ┆ f32      ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │         ┆         ┆           ┆          ┆   ┆ f32        ┆ f32        ┆ f32        ┆ f32        │
# ╞═════════╪═════════╪═══════════╪══════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 0       ┆ 34      ┆ 1         ┆ 3.889038 ┆ … ┆ -0.434355  ┆ -1.220439  ┆ 0.214211   ┆ -0.257941  │
# │ 0       ┆ 35      ┆ 1         ┆ 3.889038 ┆ … ┆ -0.112329  ┆ -1.233082  ┆ 0.131704   ┆ -0.024239  │
# │ 0       ┆ 36      ┆ 1         ┆ 3.889038 ┆ … ┆ 0.419467   ┆ -0.578848  ┆ 0.269364   ┆ 0.459819   │
# │ 0       ┆ 37      ┆ 1         ┆ 3.889038 ┆ … ┆ 0.321798   ┆ -0.683034  ┆ 0.027111   ┆ 0.075722   │
# │ 0       ┆ 38      ┆ 1         ┆ 3.889038 ┆ … ┆ 0.098249   ┆ -0.606483  ┆ -0.01076   ┆ -0.134628  │
# └─────────┴─────────┴───────────┴──────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# Ensure sorted by time_id to create batches not leaked

# %%
data = data.sort(by="time_id")

# %% [markdown]
# Define features and target

# %%
target = "responder_6"
features = [col for col in data.columns if "feature" in col]

X, y = data[features], data[target]

# %% [markdown]
# Split data

# %%
n = X.height
n_train = int(0.8 * n)
X_train = X.slice(0, n_train)
y_train = y.slice(0, n_train)

X_val = X.slice(n_train)
y_val = y.slice(n_train)

# %% [markdown]
# Data Wraper

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Model hyperameters

# %%
xgb_params = {
    "n_estimators": 50,
    "max_depth": 5,
    "learning_rate": 0.05,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "random_state": 42,
}

# %%
model = XGBRegressor(**xgb_params)

# %%
model.fit(X=X_train, y=y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=50,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_val)
r2_score(y_val, y_pred)
# Out:
# 0.004505932331085205
